# %%
from fastapi import FastAPI
from bs4 import BeautifulSoup
import requests
import uvicorn
import asyncio
import json
import pandas as pd
from io import StringIO  
from typing import List, Dict

# %%
app = FastAPI()

# %%
@app.get("/")
async def test():
    return {"message": "Hello World"}

# %%
@app.get("/llm_benchmarks/trustbit")
async def get_llm_benchmark_data_from_trustbit():
    base_url = 'https://www.trustbit.tech'
    html = requests.get(f'{base_url}/en/llm-benchmarks').text
    soup = BeautifulSoup(html, 'html.parser')
    
    links = [a['href'] for a in soup.find_all('a', href=True) if a['href'].startswith('/en/llm-leaderboard')]
    u_links = list(set(links))
    urls = [base_url + uri for uri in links]
    
    data = []
    for url in urls:
        response = requests.get(url)
    
        benchmark_html = response.text
    
        soup = BeautifulSoup(benchmark_html, 'html.parser')
        html_table = soup.find('table', class_='custom-model-table')
        if html_table == None: continue
        dfs = pd.read_html(StringIO(str(html_table)))
        # dfs is a list of DataFrames, one for each table found in the HTML
        if dfs:
            df = dfs[0]  # Assuming you want the first table
        
        title = url.split("-")[-3:]
        df.style.set_caption(" ".join(title).upper())
        # Print the DataFrame
        data.append(df.to_dict(orient='records'))
    
    return {"data": data}

# %%
base_url = 'https://www.trustbit.tech'
html = requests.get(f'{base_url}/en/llm-benchmarks').text
soup = BeautifulSoup(html, 'html.parser')

links = [a['href'] for a in soup.find_all('a', href=True) if a['href'].startswith('/en/llm-leaderboard')]
u_links = list(set(links))
urls = [base_url + uri for uri in links]

data = []
for url in urls:
    response = requests.get(url)

    benchmark_html = response.text

    soup = BeautifulSoup(benchmark_html, 'html.parser')
    html_table = soup.find('table', class_='custom-model-table')
    if html_table == None: continue
    dfs = pd.read_html(StringIO(str(html_table)))

    # dfs is a list of DataFrames, one for each table found in the HTML
    if dfs:
        df = dfs[0]  # Assuming you want the first table
    
    title = url.split("-")[-3:]
    df.style.set_caption(" ".join(title).upper())
    # Print the DataFrame
    df.replace([np.nan, float('inf'), float('-inf')], None, inplace=True)

    data.append(df.to_dict(orient='records'))

for d in data:
    print(d)
# Out:
# [{'model': nan, 'code': nan, 'crm': nan, 'docs': nan, 'integrate': nan, 'marketing': nan, 'reason': nan, 'final 🏆': nan, 'Cost': nan, 'Speed': nan}, {'model': 'GPT-4o ☁️', 'code': 90.0, 'crm': 95.0, 'docs': 100.0, 'integrate': 90.0, 'marketing': 82.0, 'reason': 75.0, 'final 🏆': 89.0, 'Cost': '1.21 €', 'Speed': '1.50 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 86.0, 'crm': 99.0, 'docs': 98.0, 'integrate': 93.0, 'marketing': 88.0, 'reason': 45.0, 'final 🏆': 85.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'Google Gemini Pro 1.5 0801 ☁️', 'code': 84.0, 'crm': 92.0, 'docs': 90.0, 'integrate': 100.0, 'marketing': 70.0, 'reason': 72.0, 'final 🏆': 85.0, 'Cost': '1.48 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 90.0, 'crm': 88.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 78.0, 'Cost': '7.04 €', 'Speed': '1.31 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 72.0, 'crm': 83.0, 'docs': 89.0, 'integrate': 78.0, 'marketing': 80.0, 'reason': 59.0, 'final 🏆': 77.0, 'Cost': '0.94 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 90.0, 'crm': 83.0, 'docs': 95.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 76.0, 'Cost': '7.04 €', 'Speed': '2.16 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 66.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 71.0, 'marketing': 75.0, 'reason': 45.0, 'final 🏆': 76.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'GPT-4o Mini ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 80.0, 'integrate': 52.0, 'marketing': 100.0, 'reason': 67.0, 'final 🏆': 75.0, 'Cost': '0.04 €', 'Speed': '1.46 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 69.0, 'crm': 88.0, 'docs': 100.0, 'integrate': 53.0, 'marketing': 76.0, 'reason': 59.0, 'final 🏆': 74.0, 'Cost': '4.69 €', 'Speed': '0.41 rps'}, {'model': 'Meta Llama3.1 405B Instruct🦙', 'code': 81.0, 'crm': 93.0, 'docs': 92.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 74.0, 'Cost': '2.39 €', 'Speed': '1.16 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 66.0, 'crm': 75.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 62.0, 'final 🏆': 73.0, 'Cost': '2.46 €', 'Speed': '0.68 rps'}, {'model': 'Mistral Large 123B v2/2407 ☁️', 'code': 68.0, 'crm': 79.0, 'docs': 68.0, 'integrate': 75.0, 'marketing': 75.0, 'reason': 71.0, 'final 🏆': 73.0, 'Cost': '0.86 €', 'Speed': '1.02 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 73.0, 'crm': 96.0, 'docs': 75.0, 'integrate': 100.0, 'marketing': 25.0, 'reason': 62.0, 'final 🏆': 72.0, 'Cost': '2.01 €', 'Speed': '0.92 rps'}, {'model': 'Meta Llama 3.1 70B Instruct f16🦙', 'code': 74.0, 'crm': 89.0, 'docs': 90.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 72.0, 'Cost': '1.79 €', 'Speed': '0.90 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 68.0, 'crm': 97.0, 'docs': 96.0, 'integrate': 63.0, 'marketing': 75.0, 'reason': 28.0, 'final 🏆': 71.0, 'Cost': '1.84 €', 'Speed': '0.59 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 68.0, 'crm': 81.0, 'docs': 73.0, 'integrate': 75.0, 'marketing': 81.0, 'reason': 48.0, 'final 🏆': 71.0, 'Cost': '0.34 €', 'Speed': '1.46 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 68.0, 'crm': 70.0, 'docs': 71.0, 'integrate': 63.0, 'marketing': 78.0, 'reason': 59.0, 'final 🏆': 68.0, 'Cost': '0.24 €', 'Speed': '2.33 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 66.0, 'crm': 86.0, 'docs': 83.0, 'integrate': 60.0, 'marketing': 88.0, 'reason': 26.0, 'final 🏆': 68.0, 'Cost': '0.09 €', 'Speed': '1.36 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 71.0, 'integrate': 60.0, 'marketing': 78.0, 'reason': 47.0, 'final 🏆': 68.0, 'Cost': '0.12 €', 'Speed': '1.43 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 56.0, 'marketing': 72.0, 'reason': 41.0, 'final 🏆': 66.0, 'Cost': '0.09 €', 'Speed': '1.77 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 63.0, 'crm': 80.0, 'docs': 76.0, 'integrate':  ...
# [{'model': nan, 'code': nan, 'crm': nan, 'docs': nan, 'integrate': nan, 'marketing': nan, 'reason': nan, 'final 🏆': nan, 'Cost': nan, 'Speed': nan}, {'model': 'GPT-4o ☁️', 'code': 90.0, 'crm': 95.0, 'docs': 100.0, 'integrate': 90.0, 'marketing': 82.0, 'reason': 75.0, 'final 🏆': 89.0, 'Cost': '1.21 €', 'Speed': '1.50 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 86.0, 'crm': 99.0, 'docs': 98.0, 'integrate': 93.0, 'marketing': 88.0, 'reason': 45.0, 'final 🏆': 85.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'Google Gemini Pro 1.5 0801 ☁️', 'code': 84.0, 'crm': 92.0, 'docs': 90.0, 'integrate': 100.0, 'marketing': 70.0, 'reason': 72.0, 'final 🏆': 85.0, 'Cost': '1.48 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 90.0, 'crm': 88.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 78.0, 'Cost': '7.04 €', 'Speed': '1.31 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 72.0, 'crm': 83.0, 'docs': 89.0, 'integrate': 78.0, 'marketing': 80.0, 'reason': 59.0, 'final 🏆': 77.0, 'Cost': '0.94 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 90.0, 'crm': 83.0, 'docs': 95.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 76.0, 'Cost': '7.04 €', 'Speed': '2.16 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 66.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 71.0, 'marketing': 75.0, 'reason': 45.0, 'final 🏆': 76.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'GPT-4o Mini ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 80.0, 'integrate': 52.0, 'marketing': 100.0, 'reason': 67.0, 'final 🏆': 75.0, 'Cost': '0.04 €', 'Speed': '1.46 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 69.0, 'crm': 88.0, 'docs': 100.0, 'integrate': 53.0, 'marketing': 76.0, 'reason': 59.0, 'final 🏆': 74.0, 'Cost': '4.69 €', 'Speed': '0.41 rps'}, {'model': 'Meta Llama3.1 405B Instruct🦙', 'code': 81.0, 'crm': 93.0, 'docs': 92.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 74.0, 'Cost': '2.39 €', 'Speed': '1.16 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 66.0, 'crm': 75.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 62.0, 'final 🏆': 73.0, 'Cost': '2.46 €', 'Speed': '0.68 rps'}, {'model': 'Mistral Large 123B v2/2407 ☁️', 'code': 68.0, 'crm': 79.0, 'docs': 68.0, 'integrate': 75.0, 'marketing': 75.0, 'reason': 71.0, 'final 🏆': 73.0, 'Cost': '0.86 €', 'Speed': '1.02 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 73.0, 'crm': 96.0, 'docs': 75.0, 'integrate': 100.0, 'marketing': 25.0, 'reason': 62.0, 'final 🏆': 72.0, 'Cost': '2.01 €', 'Speed': '0.92 rps'}, {'model': 'Meta Llama 3.1 70B Instruct f16🦙', 'code': 74.0, 'crm': 89.0, 'docs': 90.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 72.0, 'Cost': '1.79 €', 'Speed': '0.90 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 68.0, 'crm': 97.0, 'docs': 96.0, 'integrate': 63.0, 'marketing': 75.0, 'reason': 28.0, 'final 🏆': 71.0, 'Cost': '1.84 €', 'Speed': '0.59 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 68.0, 'crm': 81.0, 'docs': 73.0, 'integrate': 75.0, 'marketing': 81.0, 'reason': 48.0, 'final 🏆': 71.0, 'Cost': '0.34 €', 'Speed': '1.46 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 68.0, 'crm': 70.0, 'docs': 71.0, 'integrate': 63.0, 'marketing': 78.0, 'reason': 59.0, 'final 🏆': 68.0, 'Cost': '0.24 €', 'Speed': '2.33 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 66.0, 'crm': 86.0, 'docs': 83.0, 'integrate': 60.0, 'marketing': 88.0, 'reason': 26.0, 'final 🏆': 68.0, 'Cost': '0.09 €', 'Speed': '1.36 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 71.0, 'integrate': 60.0, 'marketing': 78.0, 'reason': 47.0, 'final 🏆': 68.0, 'Cost': '0.12 €', 'Speed': '1.43 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 56.0, 'marketing': 72.0, 'reason': 41.0, 'final 🏆': 66.0, 'Cost': '0.09 €', 'Speed': '1.77 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 63.0, 'crm': 80.0, 'docs': 76.0, 'integrate':  ...
# [{'model': nan, 'code': nan, 'crm': nan, 'docs': nan, 'integrate': nan, 'marketing': nan, 'reason': nan, 'final 🏆': nan, 'Cost': nan, 'Speed': nan}, {'model': 'GPT-4o ☁️', 'code': 90.0, 'crm': 95.0, 'docs': 100.0, 'integrate': 90.0, 'marketing': 82.0, 'reason': 75.0, 'final 🏆': 89.0, 'Cost': '1.21 €', 'Speed': '1.50 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 86.0, 'crm': 99.0, 'docs': 98.0, 'integrate': 93.0, 'marketing': 88.0, 'reason': 45.0, 'final 🏆': 85.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'Google Gemini Pro 1.5 0801 ☁️', 'code': 84.0, 'crm': 92.0, 'docs': 90.0, 'integrate': 100.0, 'marketing': 70.0, 'reason': 72.0, 'final 🏆': 85.0, 'Cost': '1.48 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 90.0, 'crm': 88.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 78.0, 'Cost': '7.04 €', 'Speed': '1.31 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 72.0, 'crm': 83.0, 'docs': 89.0, 'integrate': 78.0, 'marketing': 80.0, 'reason': 59.0, 'final 🏆': 77.0, 'Cost': '0.94 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 90.0, 'crm': 83.0, 'docs': 95.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 76.0, 'Cost': '7.04 €', 'Speed': '2.16 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 66.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 71.0, 'marketing': 75.0, 'reason': 45.0, 'final 🏆': 76.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'GPT-4o Mini ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 80.0, 'integrate': 52.0, 'marketing': 100.0, 'reason': 67.0, 'final 🏆': 75.0, 'Cost': '0.04 €', 'Speed': '1.46 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 69.0, 'crm': 88.0, 'docs': 100.0, 'integrate': 53.0, 'marketing': 76.0, 'reason': 59.0, 'final 🏆': 74.0, 'Cost': '4.69 €', 'Speed': '0.41 rps'}, {'model': 'Meta Llama3.1 405B Instruct🦙', 'code': 81.0, 'crm': 93.0, 'docs': 92.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 74.0, 'Cost': '2.39 €', 'Speed': '1.16 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 66.0, 'crm': 75.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 62.0, 'final 🏆': 73.0, 'Cost': '2.46 €', 'Speed': '0.68 rps'}, {'model': 'Mistral Large 123B v2/2407 ☁️', 'code': 68.0, 'crm': 79.0, 'docs': 68.0, 'integrate': 75.0, 'marketing': 75.0, 'reason': 71.0, 'final 🏆': 73.0, 'Cost': '0.86 €', 'Speed': '1.02 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 73.0, 'crm': 96.0, 'docs': 75.0, 'integrate': 100.0, 'marketing': 25.0, 'reason': 62.0, 'final 🏆': 72.0, 'Cost': '2.01 €', 'Speed': '0.92 rps'}, {'model': 'Meta Llama 3.1 70B Instruct f16🦙', 'code': 74.0, 'crm': 89.0, 'docs': 90.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 72.0, 'Cost': '1.79 €', 'Speed': '0.90 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 68.0, 'crm': 97.0, 'docs': 96.0, 'integrate': 63.0, 'marketing': 75.0, 'reason': 28.0, 'final 🏆': 71.0, 'Cost': '1.84 €', 'Speed': '0.59 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 68.0, 'crm': 81.0, 'docs': 73.0, 'integrate': 75.0, 'marketing': 81.0, 'reason': 48.0, 'final 🏆': 71.0, 'Cost': '0.34 €', 'Speed': '1.46 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 68.0, 'crm': 70.0, 'docs': 71.0, 'integrate': 63.0, 'marketing': 78.0, 'reason': 59.0, 'final 🏆': 68.0, 'Cost': '0.24 €', 'Speed': '2.33 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 66.0, 'crm': 86.0, 'docs': 83.0, 'integrate': 60.0, 'marketing': 88.0, 'reason': 26.0, 'final 🏆': 68.0, 'Cost': '0.09 €', 'Speed': '1.36 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 71.0, 'integrate': 60.0, 'marketing': 78.0, 'reason': 47.0, 'final 🏆': 68.0, 'Cost': '0.12 €', 'Speed': '1.43 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 56.0, 'marketing': 72.0, 'reason': 41.0, 'final 🏆': 66.0, 'Cost': '0.09 €', 'Speed': '1.77 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 63.0, 'crm': 80.0, 'docs': 76.0, 'integrate':  ...
# [{'model': nan, 'code': nan, 'crm': nan, 'docs': nan, 'integrate': nan, 'marketing': nan, 'reason': nan, 'final 🏆': nan, 'Cost': nan, 'Speed': nan}, {'model': 'GPT-4o ☁️', 'code': 90.0, 'crm': 95.0, 'docs': 100.0, 'integrate': 90.0, 'marketing': 82.0, 'reason': 75.0, 'final 🏆': 89.0, 'Cost': '1.21 €', 'Speed': '1.50 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 86.0, 'crm': 99.0, 'docs': 98.0, 'integrate': 93.0, 'marketing': 88.0, 'reason': 45.0, 'final 🏆': 85.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'Google Gemini Pro 1.5 0801 ☁️', 'code': 84.0, 'crm': 92.0, 'docs': 90.0, 'integrate': 100.0, 'marketing': 70.0, 'reason': 72.0, 'final 🏆': 85.0, 'Cost': '1.48 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 90.0, 'crm': 88.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 78.0, 'Cost': '7.04 €', 'Speed': '1.31 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 72.0, 'crm': 83.0, 'docs': 89.0, 'integrate': 78.0, 'marketing': 80.0, 'reason': 59.0, 'final 🏆': 77.0, 'Cost': '0.94 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 90.0, 'crm': 83.0, 'docs': 95.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 76.0, 'Cost': '7.04 €', 'Speed': '2.16 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 66.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 71.0, 'marketing': 75.0, 'reason': 45.0, 'final 🏆': 76.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'GPT-4o Mini ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 80.0, 'integrate': 52.0, 'marketing': 100.0, 'reason': 67.0, 'final 🏆': 75.0, 'Cost': '0.04 €', 'Speed': '1.46 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 69.0, 'crm': 88.0, 'docs': 100.0, 'integrate': 53.0, 'marketing': 76.0, 'reason': 59.0, 'final 🏆': 74.0, 'Cost': '4.69 €', 'Speed': '0.41 rps'}, {'model': 'Meta Llama3.1 405B Instruct🦙', 'code': 81.0, 'crm': 93.0, 'docs': 92.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 74.0, 'Cost': '2.39 €', 'Speed': '1.16 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 66.0, 'crm': 75.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 62.0, 'final 🏆': 73.0, 'Cost': '2.46 €', 'Speed': '0.68 rps'}, {'model': 'Mistral Large 123B v2/2407 ☁️', 'code': 68.0, 'crm': 79.0, 'docs': 68.0, 'integrate': 75.0, 'marketing': 75.0, 'reason': 71.0, 'final 🏆': 73.0, 'Cost': '0.86 €', 'Speed': '1.02 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 73.0, 'crm': 96.0, 'docs': 75.0, 'integrate': 100.0, 'marketing': 25.0, 'reason': 62.0, 'final 🏆': 72.0, 'Cost': '2.01 €', 'Speed': '0.92 rps'}, {'model': 'Meta Llama 3.1 70B Instruct f16🦙', 'code': 74.0, 'crm': 89.0, 'docs': 90.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 72.0, 'Cost': '1.79 €', 'Speed': '0.90 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 68.0, 'crm': 97.0, 'docs': 96.0, 'integrate': 63.0, 'marketing': 75.0, 'reason': 28.0, 'final 🏆': 71.0, 'Cost': '1.84 €', 'Speed': '0.59 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 68.0, 'crm': 81.0, 'docs': 73.0, 'integrate': 75.0, 'marketing': 81.0, 'reason': 48.0, 'final 🏆': 71.0, 'Cost': '0.34 €', 'Speed': '1.46 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 68.0, 'crm': 70.0, 'docs': 71.0, 'integrate': 63.0, 'marketing': 78.0, 'reason': 59.0, 'final 🏆': 68.0, 'Cost': '0.24 €', 'Speed': '2.33 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 66.0, 'crm': 86.0, 'docs': 83.0, 'integrate': 60.0, 'marketing': 88.0, 'reason': 26.0, 'final 🏆': 68.0, 'Cost': '0.09 €', 'Speed': '1.36 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 71.0, 'integrate': 60.0, 'marketing': 78.0, 'reason': 47.0, 'final 🏆': 68.0, 'Cost': '0.12 €', 'Speed': '1.43 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 56.0, 'marketing': 72.0, 'reason': 41.0, 'final 🏆': 66.0, 'Cost': '0.09 €', 'Speed': '1.77 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 63.0, 'crm': 80.0, 'docs': 76.0, 'integrate':  ...
# [{'model': 'GPT-4o ☁️', 'code': 85, 'crm': 95, 'docs': 100, 'integrate': 90, 'marketing': 82, 'reason': 75, 'final 🏆': 88, 'Cost': '1.24 €', 'Speed': '1.49 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 80, 'crm': 99, 'docs': 98, 'integrate': 93, 'marketing': 88, 'reason': 45, 'final 🏆': 84, 'Cost': '2.51 €', 'Speed': '0.83 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 67, 'crm': 83, 'docs': 89, 'integrate': 78, 'marketing': 80, 'reason': 59, 'final 🏆': 76, 'Cost': '0.97 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 80, 'crm': 88, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 76, 'Cost': '7.19 €', 'Speed': '1.26 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 60, 'crm': 97, 'docs': 100, 'integrate': 71, 'marketing': 75, 'reason': 45, 'final 🏆': 75, 'Cost': '2.51 €', 'Speed': '0.82 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 80, 'crm': 83, 'docs': 95, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 74, 'Cost': '7.19 €', 'Speed': '2.07 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 64, 'crm': 88, 'docs': 100, 'integrate': 53, 'marketing': 76, 'reason': 59, 'final 🏆': 73, 'Cost': '4.83 €', 'Speed': '0.41 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 60, 'crm': 75, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 62, 'final 🏆': 72, 'Cost': '2.52 €', 'Speed': '0.68 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 67, 'crm': 96, 'docs': 75, 'integrate': 100, 'marketing': 25, 'reason': 62, 'final 🏆': 71, 'Cost': '2.06 €', 'Speed': '0.91 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 62, 'crm': 97, 'docs': 96, 'integrate': 63, 'marketing': 75, 'reason': 28, 'final 🏆': 70, 'Cost': '1.89 €', 'Speed': '0.58 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 62, 'crm': 81, 'docs': 73, 'integrate': 75, 'marketing': 81, 'reason': 48, 'final 🏆': 70, 'Cost': '0.35 €', 'Speed': '1.39 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 62, 'crm': 70, 'docs': 71, 'integrate': 63, 'marketing': 78, 'reason': 59, 'final 🏆': 67, 'Cost': '0.24 €', 'Speed': '2.29 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 58, 'crm': 87, 'docs': 71, 'integrate': 60, 'marketing': 78, 'reason': 47, 'final 🏆': 67, 'Cost': '0.13 €', 'Speed': '1.41 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32, 'crm': 97, 'docs': 100, 'integrate': 56, 'marketing': 72, 'reason': 41, 'final 🏆': 66, 'Cost': '0.10 €', 'Speed': '1.76 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 55, 'crm': 86, 'docs': 83, 'integrate': 60, 'marketing': 88, 'reason': 26, 'final 🏆': 66, 'Cost': '0.10 €', 'Speed': '1.35 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 58, 'crm': 80, 'docs': 76, 'integrate': 49, 'marketing': 70, 'reason': 59, 'final 🏆': 65, 'Cost': '0.85 €', 'Speed': '1.88 rps'}, {'model': 'Qwen1.5 32B Chat f16 ⚠️', 'code': 64, 'crm': 90, 'docs': 82, 'integrate': 56, 'marketing': 78, 'reason': 15, 'final 🏆': 64, 'Cost': '1.02 €', 'Speed': '1.61 rps'}, {'model': 'GPT-3.5-instruct 0914 ☁️', 'code': 44, 'crm': 92, 'docs': 69, 'integrate': 60, 'marketing': 88, 'reason': 32, 'final 🏆': 64, 'Cost': '0.36 €', 'Speed': '2.12 rps'}, {'model': 'Gemma 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 62, 'crm': 67, 'docs': 84, 'integrate': 33, 'marketing': 81, 'reason': 48, 'final 🏆': 63, 'Cost': '0.22 €', 'Speed': '4.91 rps'}, {'model': 'Meta Llama 3 8B Instruct f16🦙', 'code': 74, 'crm': 62, 'docs': 68, 'integrate': 49, 'marketing': 80, 'reason': 42, 'final 🏆': 63, 'Cost': '0.35 €', 'Speed': '3.16 rps'}, {'model': 'GPT-3.5 v1/0301 ☁️', 'code': 49, 'crm': 82, 'docs': 69, 'integrate': 67, 'marketing': 82, 'reason': 24, 'final 🏆': 62, 'Cost': '0.36 €', 'Speed': '3.93 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 56, 'crm': 87, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 23, 'final 🏆': 62, 'Cost': '0.33 €', 'Speed': '3.28 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v2 1210 f16 ✅', 'code': 58, 'crm': 73, 'docs': 72, 'integrate': 45, 'marketing': 88, 'reason': 28, 'final 🏆': 61, 'Cost': '0. ...
# [{'model': 'GPT-4o ☁️', 'code': 85, 'crm': 95, 'docs': 100, 'integrate': 90, 'marketing': 82, 'reason': 75, 'final 🏆': 88, 'Cost': '1.24 €', 'Speed': '1.49 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 80, 'crm': 99, 'docs': 98, 'integrate': 93, 'marketing': 88, 'reason': 45, 'final 🏆': 84, 'Cost': '2.51 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 80, 'crm': 88, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 76, 'Cost': '7.19 €', 'Speed': '1.26 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 60, 'crm': 97, 'docs': 100, 'integrate': 71, 'marketing': 75, 'reason': 45, 'final 🏆': 75, 'Cost': '2.51 €', 'Speed': '0.82 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 80, 'crm': 83, 'docs': 95, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 74, 'Cost': '7.19 €', 'Speed': '2.07 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 64, 'crm': 88, 'docs': 100, 'integrate': 53, 'marketing': 76, 'reason': 59, 'final 🏆': 73, 'Cost': '4.83 €', 'Speed': '0.41 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 60, 'crm': 75, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 62, 'final 🏆': 72, 'Cost': '2.52 €', 'Speed': '0.68 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 67, 'crm': 96, 'docs': 75, 'integrate': 100, 'marketing': 25, 'reason': 62, 'final 🏆': 71, 'Cost': '2.06 €', 'Speed': '0.91 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 62, 'crm': 97, 'docs': 96, 'integrate': 63, 'marketing': 75, 'reason': 28, 'final 🏆': 70, 'Cost': '1.89 €', 'Speed': '0.58 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 62, 'crm': 79, 'docs': 73, 'integrate': 75, 'marketing': 81, 'reason': 48, 'final 🏆': 70, 'Cost': '0.35 €', 'Speed': '1.39 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 62, 'crm': 68, 'docs': 71, 'integrate': 63, 'marketing': 78, 'reason': 59, 'final 🏆': 67, 'Cost': '0.24 €', 'Speed': '2.29 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32, 'crm': 97, 'docs': 100, 'integrate': 56, 'marketing': 72, 'reason': 41, 'final 🏆': 66, 'Cost': '0.10 €', 'Speed': '1.76 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 58, 'crm': 85, 'docs': 71, 'integrate': 60, 'marketing': 78, 'reason': 47, 'final 🏆': 66, 'Cost': '0.13 €', 'Speed': '1.41 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 55, 'crm': 86, 'docs': 83, 'integrate': 60, 'marketing': 88, 'reason': 26, 'final 🏆': 66, 'Cost': '0.10 €', 'Speed': '1.35 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 58, 'crm': 77, 'docs': 76, 'integrate': 49, 'marketing': 70, 'reason': 59, 'final 🏆': 65, 'Cost': '0.85 €', 'Speed': '1.88 rps'}, {'model': 'Qwen1.5 32B Chat f16 ⚠️', 'code': 64, 'crm': 87, 'docs': 82, 'integrate': 56, 'marketing': 78, 'reason': 15, 'final 🏆': 64, 'Cost': '1.02 €', 'Speed': '1.61 rps'}, {'model': 'GPT-3.5-instruct 0914 ☁️', 'code': 44, 'crm': 90, 'docs': 69, 'integrate': 60, 'marketing': 88, 'reason': 32, 'final 🏆': 64, 'Cost': '0.36 €', 'Speed': '2.12 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 56, 'crm': 86, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 26, 'final 🏆': 62, 'Cost': '0.37 €', 'Speed': '2.99 rps'}, {'model': 'Meta Llama 3 8B Instruct f16🦙', 'code': 74, 'crm': 60, 'docs': 68, 'integrate': 49, 'marketing': 80, 'reason': 42, 'final 🏆': 62, 'Cost': '0.35 €', 'Speed': '3.16 rps'}, {'model': 'GPT-3.5 v1/0301 ☁️', 'code': 49, 'crm': 75, 'docs': 69, 'integrate': 67, 'marketing': 82, 'reason': 24, 'final 🏆': 61, 'Cost': '0.36 €', 'Speed': '3.93 rps'}, {'model': 'Starling 7B-alpha f16 ⚠️', 'code': 51, 'crm': 66, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 36, 'final 🏆': 60, 'Cost': '0.61 €', 'Speed': '1.80 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v1 f16 ✅', 'code': 46, 'crm': 72, 'docs': 72, 'integrate': 49, 'marketing': 88, 'reason': 31, 'final 🏆': 60, 'Cost': '0.51 €', 'Speed': '2.14 rps'}, {'model': 'Claude 3 Haiku ☁️', 'code': 59, 'crm': 69, 'docs': 64, 'integrate': 55, 'marketing': 75, 'reason': 33, 'final 🏆': 59, 'Cost': '0.08 €', 'Speed': '0. ...
# [{'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 80, 'crm': 99, 'docs': 98, 'integrate': 93, 'marketing': 88, 'reason': 45, 'final 🏆': 84, 'Cost': '2.51 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 80, 'crm': 88, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 76, 'Cost': '7.19 €', 'Speed': '1.26 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 60, 'crm': 97, 'docs': 100, 'integrate': 71, 'marketing': 75, 'reason': 45, 'final 🏆': 75, 'Cost': '2.51 €', 'Speed': '0.82 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 80, 'crm': 83, 'docs': 95, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 74, 'Cost': '7.19 €', 'Speed': '2.07 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 64, 'crm': 88, 'docs': 100, 'integrate': 53, 'marketing': 76, 'reason': 59, 'final 🏆': 73, 'Cost': '4.83 €', 'Speed': '0.41 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 60, 'crm': 75, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 62, 'final 🏆': 72, 'Cost': '2.52 €', 'Speed': '0.68 rps'}, {'model': 'Gemini Pro 1.5 ☁️', 'code': 62, 'crm': 97, 'docs': 96, 'integrate': 63, 'marketing': 75, 'reason': 28, 'final 🏆': 70, 'Cost': '1.89 €', 'Speed': '0.58 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 62, 'crm': 79, 'docs': 73, 'integrate': 75, 'marketing': 81, 'reason': 48, 'final 🏆': 70, 'Cost': '0.35 €', 'Speed': '1.39 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 62, 'crm': 68, 'docs': 71, 'integrate': 63, 'marketing': 78, 'reason': 59, 'final 🏆': 67, 'Cost': '0.24 €', 'Speed': '2.29 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 58, 'crm': 85, 'docs': 71, 'integrate': 60, 'marketing': 78, 'reason': 47, 'final 🏆': 66, 'Cost': '0.13 €', 'Speed': '1.41 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 55, 'crm': 86, 'docs': 83, 'integrate': 60, 'marketing': 88, 'reason': 26, 'final 🏆': 66, 'Cost': '0.10 €', 'Speed': '1.35 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 58, 'crm': 77, 'docs': 76, 'integrate': 49, 'marketing': 70, 'reason': 59, 'final 🏆': 65, 'Cost': '0.85 €', 'Speed': '1.88 rps'}, {'model': 'GPT-3.5-instruct 0914 ☁️', 'code': 44, 'crm': 90, 'docs': 69, 'integrate': 60, 'marketing': 88, 'reason': 32, 'final 🏆': 64, 'Cost': '0.36 €', 'Speed': '2.12 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 56, 'crm': 86, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 26, 'final 🏆': 62, 'Cost': '0.37 €', 'Speed': '2.99 rps'}, {'model': 'Meta Llama 3 8B Instruct f16🦙', 'code': 74, 'crm': 60, 'docs': 68, 'integrate': 49, 'marketing': 80, 'reason': 42, 'final 🏆': 62, 'Cost': '0.35 €', 'Speed': '3.16 rps'}, {'model': 'GPT-3.5 v1/0301 ☁️', 'code': 49, 'crm': 75, 'docs': 69, 'integrate': 67, 'marketing': 82, 'reason': 24, 'final 🏆': 61, 'Cost': '0.36 €', 'Speed': '3.93 rps'}, {'model': 'Starling 7B-alpha f16 ⚠️', 'code': 51, 'crm': 66, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 36, 'final 🏆': 60, 'Cost': '0.61 €', 'Speed': '1.80 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v1 f16 ✅', 'code': 46, 'crm': 72, 'docs': 72, 'integrate': 49, 'marketing': 88, 'reason': 31, 'final 🏆': 60, 'Cost': '0.51 €', 'Speed': '2.14 rps'}, {'model': 'Claude 3 Haiku ☁️', 'code': 59, 'crm': 69, 'docs': 64, 'integrate': 55, 'marketing': 75, 'reason': 33, 'final 🏆': 59, 'Cost': '0.08 €', 'Speed': '0.53 rps'}, {'model': 'Mixtral 8x22B API (Instruct) ☁️', 'code': 47, 'crm': 62, 'docs': 62, 'integrate': 94, 'marketing': 75, 'reason': 7, 'final 🏆': 58, 'Cost': '0.18 €', 'Speed': '3.01 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v2 1210 f16 ✅', 'code': 51, 'crm': 74, 'docs': 72, 'integrate': 41, 'marketing': 75, 'reason': 31, 'final 🏆': 57, 'Cost': '0.36 €', 'Speed': '3.05 rps'}, {'model': 'Claude 3 Sonnet ☁️', 'code': 67, 'crm': 41, 'docs': 74, 'integrate': 52, 'marketing': 78, 'reason': 30, 'final 🏆': 57, 'Cost': '0.97 €', 'Speed': '0.85 rps'}, {'model': 'Mistral Large v1/2402 ☁️', 'code': 33, 'crm': 49, 'docs': 70, 'integrate': 75, 'marketing': 84, 'reason': 25, 'final 🏆': 56, 'Cost': ...
# [{'model': 'GPT-4 v1/0314 ☁️', 'code': 80, 'crm': 88, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 76, 'Cost': '7.19 €', 'Speed': '1.26 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 60, 'crm': 97, 'docs': 100, 'integrate': 71, 'marketing': 75, 'reason': 45, 'final 🏆': 75, 'Cost': '2.51 €', 'Speed': '0.82 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 80, 'crm': 83, 'docs': 95, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 74, 'Cost': '7.19 €', 'Speed': '2.07 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 64, 'crm': 88, 'docs': 100, 'integrate': 53, 'marketing': 76, 'reason': 59, 'final 🏆': 73, 'Cost': '4.83 €', 'Speed': '0.41 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 60, 'crm': 75, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 62, 'final 🏆': 72, 'Cost': '2.52 €', 'Speed': '0.68 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 62, 'crm': 79, 'docs': 73, 'integrate': 75, 'marketing': 81, 'reason': 48, 'final 🏆': 70, 'Cost': '0.35 €', 'Speed': '1.39 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 62, 'crm': 68, 'docs': 71, 'integrate': 63, 'marketing': 78, 'reason': 59, 'final 🏆': 67, 'Cost': '0.24 €', 'Speed': '2.29 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 58, 'crm': 85, 'docs': 71, 'integrate': 60, 'marketing': 78, 'reason': 47, 'final 🏆': 66, 'Cost': '0.13 €', 'Speed': '1.41 rps'}, {'model': 'GPT-3.5-instruct 0914 ☁️', 'code': 44, 'crm': 90, 'docs': 69, 'integrate': 60, 'marketing': 88, 'reason': 32, 'final 🏆': 64, 'Cost': '0.36 €', 'Speed': '2.12 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 56, 'crm': 86, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 26, 'final 🏆': 62, 'Cost': '0.37 €', 'Speed': '2.99 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 55, 'crm': 86, 'docs': 83, 'integrate': 37, 'marketing': 88, 'reason': 26, 'final 🏆': 62, 'Cost': '0.10 €', 'Speed': '1.35 rps'}, {'model': 'GPT-3.5 v1/0301 ☁️', 'code': 49, 'crm': 75, 'docs': 69, 'integrate': 67, 'marketing': 82, 'reason': 24, 'final 🏆': 61, 'Cost': '0.36 €', 'Speed': '3.93 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v1 f16 ✅', 'code': 46, 'crm': 72, 'docs': 72, 'integrate': 49, 'marketing': 88, 'reason': 31, 'final 🏆': 60, 'Cost': '0.51 €', 'Speed': '2.14 rps'}, {'model': 'Claude 3 Haiku ☁️', 'code': 59, 'crm': 69, 'docs': 64, 'integrate': 55, 'marketing': 75, 'reason': 33, 'final 🏆': 59, 'Cost': '0.08 €', 'Speed': '0.53 rps'}, {'model': 'Starling 7B-alpha f16 ⚠️', 'code': 51, 'crm': 66, 'docs': 67, 'integrate': 45, 'marketing': 88, 'reason': 36, 'final 🏆': 59, 'Cost': '0.61 €', 'Speed': '1.80 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v2 1210 f16 ✅', 'code': 51, 'crm': 74, 'docs': 72, 'integrate': 41, 'marketing': 75, 'reason': 31, 'final 🏆': 57, 'Cost': '0.36 €', 'Speed': '3.05 rps'}, {'model': 'Claude 3 Sonnet ☁️', 'code': 67, 'crm': 41, 'docs': 74, 'integrate': 52, 'marketing': 78, 'reason': 30, 'final 🏆': 57, 'Cost': '0.97 €', 'Speed': '0.85 rps'}, {'model': 'Mistral Large v1/2402 ☁️', 'code': 33, 'crm': 49, 'docs': 70, 'integrate': 75, 'marketing': 84, 'reason': 25, 'final 🏆': 56, 'Cost': '2.19 €', 'Speed': '2.04 rps'}, {'model': 'Anthropic Claude Instant v1.2 ☁️', 'code': 51, 'crm': 75, 'docs': 65, 'integrate': 59, 'marketing': 65, 'reason': 14, 'final 🏆': 55, 'Cost': '2.15 €', 'Speed': '1.47 rps'}, {'model': 'Anthropic Claude v2.0 ☁️', 'code': 57, 'crm': 52, 'docs': 55, 'integrate': 30, 'marketing': 84, 'reason': 35, 'final 🏆': 52, 'Cost': '2.24 €', 'Speed': '0.40 rps'}, {'model': 'Anthropic Claude v2.1 ☁️', 'code': 36, 'crm': 58, 'docs': 59, 'integrate': 45, 'marketing': 75, 'reason': 33, 'final 🏆': 51, 'Cost': '2.31 €', 'Speed': '0.35 rps'}, {'model': 'Mistral 7B OpenOrca f16 ☁️', 'code': 42, 'crm': 57, 'docs': 76, 'integrate': 21, 'marketing': 78, 'reason': 26, 'final 🏆': 50, 'Cost': '0.43 €', 'Speed': '2.55 rps'}, {'model': 'Mistral 7B Instruct v0.1 f16 ☁️', 'code': 31, 'crm': 70, 'docs': 69, 'integrate': 44, 'marketing': 62, 'reason': 21, 'final 🏆' ...
# [{'model': 'GPT-4 v1/0314 ☁️', 'code': 80, 'crm': 88, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 76, 'Cost': '7.19 €', 'Speed': '1.26 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 60, 'crm': 97, 'docs': 100, 'integrate': 71, 'marketing': 75, 'reason': 45, 'final 🏆': 75, 'Cost': '2.51 €', 'Speed': '0.82 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 80, 'crm': 83, 'docs': 95, 'integrate': 52, 'marketing': 88, 'reason': 50, 'final 🏆': 74, 'Cost': '7.19 €', 'Speed': '2.07 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 60, 'crm': 75, 'docs': 98, 'integrate': 52, 'marketing': 88, 'reason': 62, 'final 🏆': 72, 'Cost': '2.52 €', 'Speed': '0.68 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 62, 'crm': 79, 'docs': 73, 'integrate': 75, 'marketing': 81, 'reason': 48, 'final 🏆': 70, 'Cost': '0.35 €', 'Speed': '1.39 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 62, 'crm': 68, 'docs': 71, 'integrate': 63, 'marketing': 78, 'reason': 59, 'final 🏆': 67, 'Cost': '0.24 €', 'Speed': '2.29 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 58, 'crm': 85, 'docs': 71, 'integrate': 60, 'marketing': 78, 'reason': 47, 'final 🏆': 66, 'Cost': '0.13 €', 'Speed': '1.41 rps'}, {'model': 'GPT-3.5-instruct 0914 ☁️', 'code': 44, 'crm': 90, 'docs': 69, 'integrate': 60, 'marketing': 88, 'reason': 32, 'final 🏆': 64, 'Cost': '0.36 €', 'Speed': '2.12 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v3 0106 f16 ✅', 'code': 56, 'crm': 86, 'docs': 67, 'integrate': 52, 'marketing': 88, 'reason': 26, 'final 🏆': 62, 'Cost': '0.37 €', 'Speed': '2.99 rps'}, {'model': 'GPT-3.5 v1/0301 ☁️', 'code': 49, 'crm': 75, 'docs': 69, 'integrate': 67, 'marketing': 82, 'reason': 24, 'final 🏆': 61, 'Cost': '0.36 €', 'Speed': '3.93 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v1 f16 ✅', 'code': 46, 'crm': 72, 'docs': 72, 'integrate': 49, 'marketing': 88, 'reason': 31, 'final 🏆': 60, 'Cost': '0.51 €', 'Speed': '2.14 rps'}, {'model': 'Starling 7B-alpha f16 ⚠️', 'code': 51, 'crm': 66, 'docs': 67, 'integrate': 45, 'marketing': 88, 'reason': 36, 'final 🏆': 59, 'Cost': '0.61 €', 'Speed': '1.80 rps'}, {'model': 'Mistral 7B OpenChat-3.5 v2 1210 f16 ✅', 'code': 51, 'crm': 74, 'docs': 72, 'integrate': 41, 'marketing': 75, 'reason': 31, 'final 🏆': 57, 'Cost': '0.36 €', 'Speed': '3.05 rps'}, {'model': 'Mistral Large v1/2402 ☁️', 'code': 33, 'crm': 49, 'docs': 70, 'integrate': 75, 'marketing': 84, 'reason': 25, 'final 🏆': 56, 'Cost': '2.19 €', 'Speed': '2.04 rps'}, {'model': 'Anthropic Claude Instant v1.2 ☁️', 'code': 51, 'crm': 75, 'docs': 65, 'integrate': 59, 'marketing': 65, 'reason': 14, 'final 🏆': 55, 'Cost': '2.15 €', 'Speed': '1.47 rps'}, {'model': 'Anthropic Claude v2.0 ☁️', 'code': 57, 'crm': 52, 'docs': 55, 'integrate': 30, 'marketing': 84, 'reason': 35, 'final 🏆': 52, 'Cost': '2.24 €', 'Speed': '0.40 rps'}, {'model': 'Anthropic Claude v2.1 ☁️', 'code': 36, 'crm': 58, 'docs': 59, 'integrate': 45, 'marketing': 75, 'reason': 33, 'final 🏆': 51, 'Cost': '2.31 €', 'Speed': '0.35 rps'}, {'model': 'Mistral 7B OpenOrca f16 ☁️', 'code': 42, 'crm': 57, 'docs': 76, 'integrate': 21, 'marketing': 78, 'reason': 26, 'final 🏆': 50, 'Cost': '0.43 €', 'Speed': '2.55 rps'}, {'model': 'Mistral 7B Instruct v0.1 f16 ☁️', 'code': 31, 'crm': 70, 'docs': 69, 'integrate': 44, 'marketing': 62, 'reason': 21, 'final 🏆': 50, 'Cost': '0.79 €', 'Speed': '1.39 rps'}, {'model': 'Llama2 13B Vicuna-1.5 f16🦙', 'code': 36, 'crm': 37, 'docs': 53, 'integrate': 39, 'marketing': 82, 'reason': 38, 'final 🏆': 48, 'Cost': '1.02 €', 'Speed': '1.07 rps'}, {'model': 'Llama2 13B Hermes f16🦙', 'code': 38, 'crm': 23, 'docs': 30, 'integrate': 61, 'marketing': 60, 'reason': 43, 'final 🏆': 42, 'Cost': '1.03 €', 'Speed': '1.06 rps'}, {'model': 'Llama2 13B Hermes b8🦙', 'code': 32, 'crm': 24, 'docs': 29, 'integrate': 61, 'marketing': 60, 'reason': 43, 'final 🏆': 42, 'Cost': '4.94 €', 'Speed': '0.22 rps'}, {'model': 'Mistral Small v1/2312 (Mixtral) ☁️', 'code': 10, 'crm': 58, 'docs': 65, 'integrate': 51, 'marke ...
# [{'model': nan, 'code': nan, 'crm': nan, 'docs': nan, 'integrate': nan, 'marketing': nan, 'reason': nan, 'final 🏆': nan, 'Cost': nan, 'Speed': nan}, {'model': 'GPT-4o ☁️', 'code': 90.0, 'crm': 95.0, 'docs': 100.0, 'integrate': 90.0, 'marketing': 82.0, 'reason': 75.0, 'final 🏆': 89.0, 'Cost': '1.21 €', 'Speed': '1.50 rps'}, {'model': 'GPT-4 Turbo v5/2024-04-09 ☁️', 'code': 86.0, 'crm': 99.0, 'docs': 98.0, 'integrate': 93.0, 'marketing': 88.0, 'reason': 45.0, 'final 🏆': 85.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'Google Gemini Pro 1.5 0801 ☁️', 'code': 84.0, 'crm': 92.0, 'docs': 90.0, 'integrate': 100.0, 'marketing': 70.0, 'reason': 72.0, 'final 🏆': 85.0, 'Cost': '1.48 €', 'Speed': '0.83 rps'}, {'model': 'GPT-4 v1/0314 ☁️', 'code': 90.0, 'crm': 88.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 78.0, 'Cost': '7.04 €', 'Speed': '1.31 rps'}, {'model': 'Claude 3.5 Sonnet ☁️', 'code': 72.0, 'crm': 83.0, 'docs': 89.0, 'integrate': 78.0, 'marketing': 80.0, 'reason': 59.0, 'final 🏆': 77.0, 'Cost': '0.94 €', 'Speed': '0.09 rps'}, {'model': 'GPT-4 v2/0613 ☁️', 'code': 90.0, 'crm': 83.0, 'docs': 95.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 50.0, 'final 🏆': 76.0, 'Cost': '7.04 €', 'Speed': '2.16 rps'}, {'model': 'GPT-4 Turbo v4/0125-preview ☁️', 'code': 66.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 71.0, 'marketing': 75.0, 'reason': 45.0, 'final 🏆': 76.0, 'Cost': '2.45 €', 'Speed': '0.84 rps'}, {'model': 'GPT-4o Mini ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 80.0, 'integrate': 52.0, 'marketing': 100.0, 'reason': 67.0, 'final 🏆': 75.0, 'Cost': '0.04 €', 'Speed': '1.46 rps'}, {'model': 'Claude 3 Opus ☁️', 'code': 69.0, 'crm': 88.0, 'docs': 100.0, 'integrate': 53.0, 'marketing': 76.0, 'reason': 59.0, 'final 🏆': 74.0, 'Cost': '4.69 €', 'Speed': '0.41 rps'}, {'model': 'Meta Llama3.1 405B Instruct🦙', 'code': 81.0, 'crm': 93.0, 'docs': 92.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 74.0, 'Cost': '2.39 €', 'Speed': '1.16 rps'}, {'model': 'GPT-4 Turbo v3/1106-preview ☁️', 'code': 66.0, 'crm': 75.0, 'docs': 98.0, 'integrate': 52.0, 'marketing': 88.0, 'reason': 62.0, 'final 🏆': 73.0, 'Cost': '2.46 €', 'Speed': '0.68 rps'}, {'model': 'Mistral Large 123B v2/2407 ☁️', 'code': 68.0, 'crm': 79.0, 'docs': 68.0, 'integrate': 75.0, 'marketing': 75.0, 'reason': 71.0, 'final 🏆': 73.0, 'Cost': '0.86 €', 'Speed': '1.02 rps'}, {'model': 'Gemini Pro 1.5 0514 ☁️', 'code': 73.0, 'crm': 96.0, 'docs': 75.0, 'integrate': 100.0, 'marketing': 25.0, 'reason': 62.0, 'final 🏆': 72.0, 'Cost': '2.01 €', 'Speed': '0.92 rps'}, {'model': 'Meta Llama 3.1 70B Instruct f16🦙', 'code': 74.0, 'crm': 89.0, 'docs': 90.0, 'integrate': 55.0, 'marketing': 75.0, 'reason': 46.0, 'final 🏆': 72.0, 'Cost': '1.79 €', 'Speed': '0.90 rps'}, {'model': 'Gemini Pro 1.5 0409 ☁️', 'code': 68.0, 'crm': 97.0, 'docs': 96.0, 'integrate': 63.0, 'marketing': 75.0, 'reason': 28.0, 'final 🏆': 71.0, 'Cost': '1.84 €', 'Speed': '0.59 rps'}, {'model': 'GPT-3.5 v2/0613 ☁️', 'code': 68.0, 'crm': 81.0, 'docs': 73.0, 'integrate': 75.0, 'marketing': 81.0, 'reason': 48.0, 'final 🏆': 71.0, 'Cost': '0.34 €', 'Speed': '1.46 rps'}, {'model': 'GPT-3.5 v3/1106 ☁️', 'code': 68.0, 'crm': 70.0, 'docs': 71.0, 'integrate': 63.0, 'marketing': 78.0, 'reason': 59.0, 'final 🏆': 68.0, 'Cost': '0.24 €', 'Speed': '2.33 rps'}, {'model': 'Gemini Pro 1.0 ☁️', 'code': 66.0, 'crm': 86.0, 'docs': 83.0, 'integrate': 60.0, 'marketing': 88.0, 'reason': 26.0, 'final 🏆': 68.0, 'Cost': '0.09 €', 'Speed': '1.36 rps'}, {'model': 'GPT-3.5 v4/0125 ☁️', 'code': 63.0, 'crm': 87.0, 'docs': 71.0, 'integrate': 60.0, 'marketing': 78.0, 'reason': 47.0, 'final 🏆': 68.0, 'Cost': '0.12 €', 'Speed': '1.43 rps'}, {'model': 'Gemini 1.5 Flash 0514 ☁️', 'code': 32.0, 'crm': 97.0, 'docs': 100.0, 'integrate': 56.0, 'marketing': 72.0, 'reason': 41.0, 'final 🏆': 66.0, 'Cost': '0.09 €', 'Speed': '1.77 rps'}, {'model': 'Cohere Command R+ ☁️', 'code': 63.0, 'crm': 80.0, 'docs': 76.0, 'integrate':  ...

# %%
if __name__ == "__main__":
    config = uvicorn.Config(app)
    server = uvicorn.Server(config)
    loop = asyncio.get_running_loop()
    loop.create_task(server.serve())
# Out:
# INFO:     Started server process [86054]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:58416 - "GET /llm_benchmarks/trustbit HTTP/1.1" 500 Internal Server Error
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/uvicorn/protocols/http/httptools_impl.py", line 411, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/uvicorn/middleware/proxy_headers.py", line 69, in __call__
#     return await self.app(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/fastapi/applications.py", line 1054, in __call__
#     await super().__call__(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/applications.py", line 123, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/middleware/errors.py", line 186, in __call__
#     raise exc
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/middleware/exceptions.py", line 65, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/routing.py", line 756, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/routing.py", line 776, in app
#     await route.handle(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/routing.py", line 297, in handle
#     await self.app(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/routing.py", line 77, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/_exception_handler.py", line 64, in wrapped_app
#     raise exc
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/_exception_handler.py", line 53, in wrapped_app
#     await app(scope, receive, sender)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/routing.py", line 72, in app
#     response = await func(request)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/fastapi/routing.py", line 307, in app
#     response = actual_response_class(content, **response_args)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/responses.py", line 184, in __init__
#     super().__init__(content, status_code, headers, media_type, background)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/responses.py", line 41, in __init__
#     self.body = self.render(content)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/site-packages/starlette/responses.py", line 187, in render
#     return json.dumps(
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/json/__init__.py", line 238, in dumps
#     **kw).encode(obj)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/json/encoder.py", line 199, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#   File "/Users/romanschmidtke/miniconda3/lib/python3.10/json/encoder.py", line 257, in iterencode
#     return _iterencode(o, 0)
# ValueError: Out of range float values are not JSON compliant
